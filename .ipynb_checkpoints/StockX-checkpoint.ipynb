# %% [markdown]
# # StockX Data Contest 2019
# Kayleigh James, jamesmk@umich.edu
# ## Import Data and Clean

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from pytrends.request import TrendReq

plt.style.use('seaborn-darkgrid')
df = pd.read_excel('StockX-Data-Contest-2019-3.xlsx',error_bad_lines=False) 
df.head(10)
# Out:
#   Order Date   Brand                                   Sneaker Name  \
# 0 2017-09-01   Yeezy           Adidas-Yeezy-Boost-350-Low-V2-Beluga
# 1 2017-09-01   Yeezy    Adidas-Yeezy-Boost-350-V2-Core-Black-Copper
# 2 2017-09-01   Yeezy     Adidas-Yeezy-Boost-350-V2-Core-Black-Green
# 3 2017-09-01   Yeezy       Adidas-Yeezy-Boost-350-V2-Core-Black-Red
# 4 2017-09-01   Yeezy  Adidas-Yeezy-Boost-350-V2-Core-Black-Red-2017
# 5 2017-09-01   Yeezy  Adidas-Yeezy-Boost-350-V2-Core-Black-Red-2017
# 6 2017-09-01   Yeezy     Adidas-Yeezy-Boost-350-V2-Core-Black-White
# 7 2017-09-01   Yeezy          Adidas-Yeezy-Boost-350-V2-Cream-White
# 8 2017-09-01   Yeezy          Adidas-Yeezy-Boost-350-V2-Cream-White
# 9 2017-09-01   Yeezy          Adidas-Yeezy-Boost-350-V2-Cream-White
#
#    Sale Price  Retail Price Release Date  Shoe Size  Buyer Region
# 0      1097.0           220   2016-09-24       11.0    California
# 1       685.0           220   2016-11-23       11.0    California
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99956 entries, 0 to 99955
# Data columns (total 8 columns):
# Order Date      99956 non-null datetime64[ns]
# Brand           99956 non-null object
# Sneaker Name    99956 non-null object
# Sale Price      99956 non-null float64
# Retail Price    99956 non-null int64
# Release Date    99956 non-null datetime64[ns]
# Shoe Size       99956 non-null float64
# Buyer Region    99956 non-null object
# dtypes: datetime64[ns](2), float64(2), int64(1), object(3)
# memory usage: 6.1+ MB

# %%
df["Profit"] = df["Sale Price"] - df["Retail Price"]
df.head()
# Out:
#   Order Date   Brand                                   Sneaker Name  \
# 0 2017-09-01   Yeezy           Adidas-Yeezy-Boost-350-Low-V2-Beluga
# 1 2017-09-01   Yeezy    Adidas-Yeezy-Boost-350-V2-Core-Black-Copper
# 2 2017-09-01   Yeezy     Adidas-Yeezy-Boost-350-V2-Core-Black-Green
# 3 2017-09-01   Yeezy       Adidas-Yeezy-Boost-350-V2-Core-Black-Red
# 4 2017-09-01   Yeezy  Adidas-Yeezy-Boost-350-V2-Core-Black-Red-2017
#
#    Sale Price  Retail Price Release Date  Shoe Size  Buyer Region  Profit
# 0      1097.0           220   2016-09-24       11.0    California   877.0
# 1       685.0           220   2016-11-23       11.0    California   465.0
# 2       690.0           220   2016-11-23       11.0    California   470.0
# 3      1075.0           220   2016-11-23       11.5      Kentucky   855.0
# 4       828.0           220   2017-02-11       11.0  Rhode Island   608.0

# %% [markdown]
# Need to convert the object types into categorical types.

# %%
df['Brand'] = pd.Categorical(df['Brand'])
df['Sneaker Name'] = pd.Categorical(df['Sneaker Name'])
df['Buyer Region'] = pd.Categorical(df['Buyer Region'])
df['Order Date'] = pd.to_datetime(df['Order Date'], format='%m/%d/%Y %I:%M:%S %p')
df.index = pd.DatetimeIndex(df['Order Date']) #make date the index of the data
df.info() #check to make sure columns are all the correct data types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 99956 entries, 2017-09-01 to 2019-02-13
# Data columns (total 9 columns):
# Order Date      99956 non-null datetime64[ns]
# Brand           99956 non-null category
# Sneaker Name    99956 non-null category
# Sale Price      99956 non-null float64
# Retail Price    99956 non-null int64
# Release Date    99956 non-null datetime64[ns]
# Shoe Size       99956 non-null float64
# Buyer Region    99956 non-null category
# Profit          99956 non-null float64
# dtypes: category(3), datetime64[ns](2), float64(3), int64(1)
# memory usage: 5.6 MB

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df2 = df.drop(['Order Date','Brand','Sneaker Name', 'Sale Price','Retail Price', 'Release Date', 'Buyer Region'], axis=1)
df2 = df2.groupby('Shoe Size', as_index=False)['Profit'].mean()
sns.set_style("darkgrid")
plt.title("Shoe Size vs. Average Profit")
plt.plot( 'Shoe Size', 'Profit', data=df2, linestyle='-', marker='o')
plt.show()

# %%
sns.set_style("whitegrid")
df3 = df.drop(['Order Date','Sneaker Name', 'Sale Price','Retail Price', 'Release Date', 'Buyer Region'], axis=1)
df3.head()

df3.info()
plt.figure(figsize=(16, 10))
sns.set_context("poster")
ax = sns.scatterplot(x="Shoe Size", y="Profit", palette="Greens_r",hue="Brand",data = df3,s=200)
ax.set_title('How Brand and Shoe Size Affect Profit on StockX')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 99956 entries, 2017-09-01 to 2019-02-13
# Data columns (total 3 columns):
# Brand        99956 non-null category
# Shoe Size    99956 non-null float64
# Profit       99956 non-null float64
# dtypes: category(1), float64(2)
# memory usage: 4.9 MB
# Text(0.5,1,'How Brand and Shoe Size Affect Profit on StockX')

# %%
ax.figure.savefig("StockXPLot.png")

# %% [markdown]
# From this graph, we can see that there is clearly some sort of clustering when the brand was plotted based on shoe size and profit from the sale.  I will run with this idea and train several classification algorithms to see which one provides the most accurate result for classifying the brand of shoe based on only shoe size and profit.

# %% [markdown]
# ## Logistic Regression

# %%
df.head()
df_log_reg = df.drop(['Sneaker Name','Release Date', 'Order Date', 'Buyer Region', 'Sale Price', 'Retail Price'], axis=1)
df_log_reg.head()
df_log_reg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 99956 entries, 2017-09-01 to 2019-02-13
# Data columns (total 3 columns):
# Brand        99956 non-null category
# Shoe Size    99956 non-null float64
# Profit       99956 non-null float64
# dtypes: category(1), float64(2)
# memory usage: 2.4 MB

# %% [markdown]
# Now we want to convert Yeezy and Off-White into 1 and 0 so we can use logistic regression to classify the data.  Yeezy's will now be a '1' and Off-White will now be '0'.

# %%
df_log_reg['Brand'] = (df_log_reg['Brand'] !='Off-White').astype(int)
df_log_reg.head()
df_log_reg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 99956 entries, 2017-09-01 to 2019-02-13
# Data columns (total 3 columns):
# Brand        99956 non-null int64
# Shoe Size    99956 non-null float64
# Profit       99956 non-null float64
# dtypes: float64(2), int64(1)
# memory usage: 3.1 MB

# %% [markdown]
# Now all of our data should be in the correct format.  We will now proceed with training a logistic regression model to predict Brand based off of Sale Price, Retail Price, Shoe Size, Buyer Region, and Profit.

# %%
y = df_log_reg['Brand']
X = df_log_reg.drop('Brand', axis=1)
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
y_pred = logreg.predict(X_test)
print('Accuracy of logistic regression classifier on training set: {:.2f}'.format(logreg.score(X_train, y_train)))
print('Accuracy of logistic regression classifier on test set: {:.2f}'.format(logreg.score(X_test, y_test)))
# Out:
# Accuracy of logistic regression classifier on training set: 0.85
# Accuracy of logistic regression classifier on test set: 0.85
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %% [markdown]
# ## Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
bayes = GaussianNB()
bayes.fit(X_train, y_train)
y_pred = bayes.predict(X_test)
print('Accuracy of Naive Bayes on training set: {:.2f}'.format(bayes.score(X_train, y_train)))
print('Accuracy of Naive Bayes classifier on test set: {:.2f}'.format(bayes.score(X_test, y_test)))
# Out:
# Accuracy of Naive Bayes on training set: 0.83
# Accuracy of Naive Bayes classifier on test set: 0.84

# %% [markdown]
# ## Decision Tree

# %%
from sklearn import tree
dec_tree = tree.DecisionTreeClassifier()
dec_tree.fit(X_train, y_train)
y_pred = dec_tree.predict(X_test)
print('Accuracy of Decision Tree on training set: {:.2f}'.format(dec_tree.score(X_train, y_train)))
print('Accuracy of Decision Tree classifier on test set: {:.2f}'.format(dec_tree.score(X_test, y_test)))
# Out:
# Accuracy of Decision Tree on training set: 0.90
# Accuracy of Decision Tree classifier on test set: 0.86

# %% [markdown]
# We can see that out of Logistic Regression, Naive Bayes, and a Decision Tree that using a Decision Tree was the best way to classify the sale as either a Yeezy shoe or an Off-White shoe.

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.73      0.74      8142
#            1       0.90      0.90      0.90     21845
#
#    micro avg       0.86      0.86      0.86     29987
#    macro avg       0.82      0.82      0.82     29987
# weighted avg       0.86      0.86      0.86     29987

# %% [markdown]
# ## Conclusion

# %% [markdown]
# As we can see, with only two features, Profit (Sale Price - Retail Price) and Shoe Size, we can predict with over 86% accuracy the brand of shoe that was sold in a sale.  The best classification algorithm for this was the Decision Tree algorithm, although both Naive Bayes and Logistic Regression provided at least 83%.  This is a surprisingly high accuracy considering that only two features were used to build the model.  This can provide business value to StockX as it can provide information about what brand of shoe to buy and resell if they want high profit for a given shoe size.
