# %% [markdown]
# # StockX Data Contest 2019
# Kayleigh James, jamesmk@umich.edu
# ## Import Data and Clean

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from pytrends.request import TrenReq

plt.style.use('seaborn-darkgrid')
df = pd.read_excel('StockX-Data-Contest-2019-3.xlsx',error_bad_lines=False) 
df.head(10)
# Out:
#   Order Date   Brand                                   Sneaker Name  \
# 0 2017-09-01   Yeezy           Adidas-Yeezy-Boost-350-Low-V2-Beluga
# 1 2017-09-01   Yeezy    Adidas-Yeezy-Boost-350-V2-Core-Black-Copper
# 2 2017-09-01   Yeezy     Adidas-Yeezy-Boost-350-V2-Core-Black-Green
# 3 2017-09-01   Yeezy       Adidas-Yeezy-Boost-350-V2-Core-Black-Red
# 4 2017-09-01   Yeezy  Adidas-Yeezy-Boost-350-V2-Core-Black-Red-2017
# 5 2017-09-01   Yeezy  Adidas-Yeezy-Boost-350-V2-Core-Black-Red-2017
# 6 2017-09-01   Yeezy     Adidas-Yeezy-Boost-350-V2-Core-Black-White
# 7 2017-09-01   Yeezy          Adidas-Yeezy-Boost-350-V2-Cream-White
# 8 2017-09-01   Yeezy          Adidas-Yeezy-Boost-350-V2-Cream-White
# 9 2017-09-01   Yeezy          Adidas-Yeezy-Boost-350-V2-Cream-White
#
#    Sale Price  Retail Price Release Date  Shoe Size  Buyer Region
# 0      1097.0           220   2016-09-24       11.0    California
# 1       685.0           220   2016-11-23       11.0    California
# 2       690.0           220   2016-11-23       11.0    California
# 3      1075.0           220   2016-11-23       11.5      Kentucky
# 4       828.0           220   2017-02-11       11.0  Rhode Island
# 5       798.0           220   2017-02-11        8.5      Michigan
# 6       784.0           220   2016-12-17       11.0    California
# 7       460.0           220   2017-04-29       10.0      New York
# 8       465.0           220   2017-04-29       11.0        Kansas
# 9       465.0           220   2017-04-29       11.0       Florida

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99956 entries, 0 to 99955
# Data columns (total 8 columns):
# Order Date      99956 non-null datetime64[ns]
# Brand           99956 non-null object
# Sneaker Name    99956 non-null object
# Sale Price      99956 non-null float64
# Retail Price    99956 non-null int64
# Release Date    99956 non-null datetime64[ns]
# Shoe Size       99956 non-null float64
# Buyer Region    99956 non-null object
# dtypes: datetime64[ns](2), float64(2), int64(1), object(3)
# memory usage: 6.1+ MB

# %% [markdown]
# Need to convert the object types into categorical types.

# %%
df['Brand'] = pd.Categorical(df['Brand'])
df['Sneaker Name'] = pd.Categorical(df['Sneaker Name'])
df['Buyer Region'] = pd.Categorical(df['Buyer Region'])
df['Order Date'] = pd.to_datetime(df['Order Date'], format='%m/%d/%Y %I:%M:%S %p')
df.index = pd.DatetimeIndex(df['Order Date']) #make date the index of the data
df.info() #check to make sure columns are all the correct data types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 99956 entries, 2017-09-01 to 2019-02-13
# Data columns (total 8 columns):
# Order Date      99956 non-null datetime64[ns]
# Brand           99956 non-null category
# Sneaker Name    99956 non-null category
# Sale Price      99956 non-null float64
# Retail Price    99956 non-null int64
# Release Date    99956 non-null datetime64[ns]
# Shoe Size       99956 non-null float64
# Buyer Region    99956 non-null category
# dtypes: category(3), datetime64[ns](2), float64(2), int64(1)
# memory usage: 4.9 MB

# %% [markdown]
# ## Exploratory Data Analysis

# %%
sns.lmplot( x= 'Retail Price', y= "Sale Price", data=df, fit_reg=False, hue='Retail Price', legend=False, palette="Greens")

# %%
plt.figure(figsize=(11,5))
df.resample('M').size().plot(legend=False)
plt.title('Off-White x Nike and Yeezy 350 Sales from 9/1/2017 to Now')
plt.xlabel('Months')
plt.ylabel('Number of Orders')
plt.show()

# %% [markdown]
# Note: Each year around December there is a large spark.  Is it due to Christmas or due to a new release?
#
# Now, plot each feature to see if we notice anything interesting going on.

# %%
g = sns.stripplot(x="Sneaker Name", y="Sale Price", data=df, palette="Greens")
g.set_xticklabels(g.get_xticklabels(), rotation=30)
# Out:
# [Text(0,0,'Adidas-Yeezy-Boost-350-Low-Moonrock'),
#  Text(0,0,'Adidas-Yeezy-Boost-350-Low-Oxford-Tan'),
#  Text(0,0,'Adidas-Yeezy-Boost-350-Low-Pirate-Black-2015'),
#  Text(0,0,'Adidas-Yeezy-Boost-350-Low-Pirate-Black-2016'),
#  Text(0,0,'Adidas-Yeezy-Boost-350-Low-Turtledove'),
#  Text(0,0,'Adidas-Yeezy-Boost-350-Low-V2-Beluga'),
#  Text(0,0,'Adidas-Yeezy-Boost-350-V2-Beluga-2pt0'),
#  Text(0,0,'Adidas-Yeezy-Boost-350-V2-Blue-Tint'),
#  Text(0,0,'Adidas-Yeezy-Boost-350-V2-Core-Black-Copper'),
#  Text(0,0,'Adidas-Yeezy-Boost-350-V2-Core-Black-Green'),
#  Text(0,0,'Adidas-Yeezy-Boost-350-V2-Core-Black-Red'),
#  Text(0,0,'Adidas-Yeezy-Boost-350-V2-Core-Black-Red-2017'),
#  Text(0,0,'Adidas-Yeezy-Boost-350-V2-Core-Black-White'),
#  Text(0,0,'Adidas-Yeezy-Boost-350-V2-Cream-White'),
#  Text(0,0,'Adidas-Yeezy-Boost-350-V2-Semi-Frozen-Yellow'),
#  Text(0,0,'Adidas-Yeezy-Boost-350-V2-Sesame'),
#  Text(0,0,'Adidas-Yeezy-Boost-350-V2-Zebra'),
#  Text(0,0,'Air-Jordan-1-Retro-High-Off-White-Chicago'),
#  Text(0,0,'Air-Jordan-1-Retro-High-Off-White-University-Blue'),
#  Text(0,0,'Air-Jordan-1-Retro-High-Off-White-White'),
#  Text(0,0,'Nike-Air-Force-1-Low-Off-White'),
#  Text(0,0,'Nike-Air-Force-1-Low-Off-White-Black-White'),
#  Text(0,0,'Nike-Air-Force-1-Low-Off-White-Volt'),
#  Text(0,0,'Nike-Air-Force-1-Low-Virgil-Abloh-Off-White-AF100'),
#  Text(0,0,'Nike-Air-Max-90-Off-White'),
#  Text(0,0,'Nike-Air-Max-90-Off-White-Black'),
#  Text(0,0,'Nike-Air-Max-90-Off-White-Desert-Ore'),
#  Text(0,0,'Nike-Air-Max-97-Off-White'),
#  Text(0,0,'Nike-Air-Max-97-Off-White-Black'),
#  Text(0,0,'Nike-Air-Max-97-Off-White-Elemental-Rose-Queen'),
#  Text(0,0,'Nike-Air-Max-97-Off-White-Menta'),
#  Text(0,0,'Nike-Air-Presto-Off-White'),
#  Text(0,0,'Nike-Air-Presto-Off-White-Black-2018'),
#  Text(0,0,'Nike-Air-Presto-Off-White-White-2018'),
#  Text(0,0,'Nike-Air-VaporMax-Off-White'),
#  Text(0,0,'Nike-Air-VaporMax-Off-White-2018'),
#  Text(0,0,'Nike-Air-VaporMax-Off-White-Black'),
#  Text(0,0,'Nike-Blazer-Mid-Off-White'),
#  Text(0,0,'Nike-Blazer-Mid-Off-White-All-Hallows-Eve'),
#  Text(0,0,'Nike-Blazer-Mid-Off-White-Grim-Reaper'),
#  Text(0,0,'Nike-Blazer-Mid-Off-White-Wolf-Grey'),
#  Text(0,0,'Nike-React-Hyperdunk-2017-Flyknit-Off-White'),
#  Text(0,0,'Nike-Zoom-Fly-Mercurial-Off-White-Black'),
#  Text(0,0,'Nike-Zoom-Fly-Mercurial-Off-White-Total-Orange'),
#  Text(0,0,'Nike-Zoom-Fly-Off-White'),
#  Text(0,0,'Nike-Zoom-Fly-Off-White-Black-Silver'),
#  Text(0,0,'Nike-Zoom-Fly-Off-White-Pink'),
#  Text(0,0,'adidas-Yeezy-Boost-350-V2-Butter'),
#  Text(0,0,'adidas-Yeezy-Boost-350-V2-Static'),
#  Text(0,0,'adidas-Yeezy-Boost-350-V2-Static-Reflective')]

# %%
g = sns.stripplot(x="Buyer Region", y="Sale Price", data=df, palette="Greens")
g.set_xticklabels(g.get_xticklabels(), rotation=30)
# Out:
# [Text(0,0,'Alabama'),
#  Text(0,0,'Alaska'),
#  Text(0,0,'Arizona'),
#  Text(0,0,'Arkansas'),
#  Text(0,0,'California'),
#  Text(0,0,'Colorado'),
#  Text(0,0,'Connecticut'),
#  Text(0,0,'Delaware'),
#  Text(0,0,'District of Columbia'),
#  Text(0,0,'Florida'),
#  Text(0,0,'Georgia'),
#  Text(0,0,'Hawaii'),
#  Text(0,0,'Idaho'),
#  Text(0,0,'Illinois'),
#  Text(0,0,'Indiana'),
#  Text(0,0,'Iowa'),
#  Text(0,0,'Kansas'),
#  Text(0,0,'Kentucky'),
#  Text(0,0,'Louisiana'),
#  Text(0,0,'Maine'),
#  Text(0,0,'Maryland'),
#  Text(0,0,'Massachusetts'),
#  Text(0,0,'Michigan'),
#  Text(0,0,'Minnesota'),
#  Text(0,0,'Mississippi'),
#  Text(0,0,'Missouri'),
#  Text(0,0,'Montana'),
#  Text(0,0,'Nebraska'),
#  Text(0,0,'Nevada'),
#  Text(0,0,'New Hampshire'),
#  Text(0,0,'New Jersey'),
#  Text(0,0,'New Mexico'),
#  Text(0,0,'New York'),
#  Text(0,0,'North Carolina'),
#  Text(0,0,'North Dakota'),
#  Text(0,0,'Ohio'),
#  Text(0,0,'Oklahoma'),
#  Text(0,0,'Oregon'),
#  Text(0,0,'Pennsylvania'),
#  Text(0,0,'Rhode Island'),
#  Text(0,0,'South Carolina'),
#  Text(0,0,'South Dakota'),
#  Text(0,0,'Tennessee'),
#  Text(0,0,'Texas'),
#  Text(0,0,'Utah'),
#  Text(0,0,'Vermont'),
#  Text(0,0,'Virginia'),
#  Text(0,0,'Washington'),
#  Text(0,0,'West Virginia'),
#  Text(0,0,'Wisconsin'),
#  Text(0,0,'Wyoming')]
